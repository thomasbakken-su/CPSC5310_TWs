# %% [markdown]
# ### TW3: Exploratory Data Analysis on COVID-19 Datasets
#
#
# ### Learning the data using visualization and simple linear regression
#
# 1. First, run the example and understand the ML process and be familir with Python package functions for simple linear regression.
#
# 2. Apply exploratory data analysis and simple regression on COVID-19 dataset(s).

# %% [markdown]
# #### Write your name
#
# -

# %% [markdown]
# ###  Simple Linear Regression example
#
# Follow the code and observe the results

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# %%
# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# %% [markdown]
# This function just merges the OECD's life satisfaction data and the IMF's GDP per capita data. It's a bit too long and boring and it's not specific to Machine Learning, which is why I left it out of the book.

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# The code expects the data files to be located in the current directory. Fetch the files in datasets/lifesat.

# %%
import os
datapath = os.path.join("datasets", "lifesat", "")

# %%
# To plot pretty figures directly within Jupyter
# %matplotlib inline
import matplotlib as mpl

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Download the data
import urllib
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
os.makedirs(datapath, exist_ok=True)

for filename in ("oecd_bli_2015.csv", "gdp_per_capita.csv"):
    print("Downloading", filename)
    url = DOWNLOAD_ROOT + "datasets/lifesat/" + filename
    urllib.request.urlretrieve(url, datapath + filename)

# %% [markdown]
# #### Load the data into a DataFrame

# %%
# Code example of load the data and prepared the data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# %% [markdown]
# #### Select the data and visualize it

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    
    return full_country_stats[['GDP per capita', 'Life satisfaction']].iloc[keep_indices]

# %%
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)

X = np.c_[country_stats['GDP per capita']]
y = np.c_[country_stats['Life satisfaction']]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# %% [markdown]
# ### Build a simple regression model

# %% [markdown]
# #### Create a simple linear regression
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# import model
from sklearn.linear_model import LinearRegression

# Create a simple linear regression model
model = LinearRegression()

# Train the model (we use all data for training --> Later we will divide the data into training data and testing data)
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predict y for a new X value

# %%
# Make a prediction for Cyprus 
# new data value 22587 for Cyprus's GDP per capita

model.predict([[22587]])
# Out:
# array([[5.96242338]])

# %% [markdown]
# #### Plot a scatter graph together with the regression function

# %%
# Plot scatterplot 
plt.scatter(X, y, c='red', label='observed')
plt.legend(loc='best')

plt.xlabel('GDP per capita')
plt.ylabel('Life satisfaction')
plt.title('Regression')

# plot the regression function

plt.plot(X, model.predict(X), c='g', label='fitted', linewidth=2)
plt.show()

# %% [markdown]
# ## Model evaluation metrics for regression models
#
# Evaluation metrics for classification problems, such as **accuracy**, are not useful for regression problems. Instead, we need evaluation metrics designed for comparing continuous values.
#
# Let's create some example numeric predictions, and calculate **three common evaluation metrics** for regression problems:
#
# See more details: https://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$

# %% [markdown]
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$

# %% [markdown]
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %% [markdown]
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# ## The R2 ("r-squared") Regression Score
#
# - Measures how well a prediction model for regression fits the given data.
#
# - The score is between 0 and 1:
#
#      - A value of 0 corresponds to a constant model that predicts the mean value of all training target values.
#
#      - A value of 1 corresponds to perfect prediction
#
# - Also known as "coefficient of determination"

# %% [markdown]
# ### Model Evaluation Example

# %% [markdown]
# #### 1. Preparing X and y using pandas
# - We already did this process above
# - scikit-learn expects X (feature matrix) and y (response vector) to be NumPy arrays.
# - However, pandas is built on top of NumPy.
# - Thus, X can be a pandas DataFrame and y can be a pandas Series!
#
# See more details about Pandas Series and Numpy
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %% [markdown]
# #### 2. Splitting X and y into training and testing sets
#
# We are using the same data that is stored X, y above.

# %%
from sklearn.model_selection import train_test_split

# split the data into training and testing (test data size 30%)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.3, random_state=1)

# %% [markdown]
# #### 3. Linear regression in scikit-learn

# %%
# import model
from sklearn.linear_model import LinearRegression

# instantiate a simple linear regression model 
linreg = LinearRegression()


# fit the model to the training data (learn the coefficients)
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### 4. Making predictions for testing data
#
# Use X_test

# %%
# make predictions on the testing set
y_pred = linreg.predict(X_test)
y_pred
# Out:
# array([[6.59031623],
#        [6.90629497],
#        [6.82350342],
#        [6.90057464],
#        [7.24870458],
#        [6.88774681],
#        [5.42891846],
#        [6.12434396],
#        [7.19687366]])

# %% [markdown]
# #### 5. Computing the RMSE
#
# https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from sklearn import metrics

rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse
# Out:
# 0.39596209321120795

# %% [markdown]
# #### 6. K Cross Validation and Learning Curve

# %%
import statistics as st
from sklearn.model_selection import KFold # import k-fold validation

kf = KFold(n_splits=3, random_state=None, shuffle=True) # Define the split - into 3 folds 

kf.get_n_splits(X) # returns the number of splitting iterations in the cross-validator

print(kf)
# Out:
# KFold(n_splits=3, random_state=None, shuffle=True)

# %% [markdown]
# ##### Setting up a testbed using KFold

# %%
# Let's create a new simple linear regressor
linreg = LinearRegression()

# Conduct 3-fold cross validation
rmse = []
r2 = []
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    linreg.fit(X_train, y_train)
    y_pred = linreg.predict(X_test)
    
    rmse.append(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    r2.append(metrics.r2_score(y_test, y_pred))

print(rmse)
print(r2)
# Out:
# [0.46755919335467, 0.4823823349897365, 0.44278343333714004]
# [0.7052162900613947, 0.3977931751807706, 0.6546187325823429]

# %% [markdown]
# #### Learning Curve
#
# Check the details for learning curve
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.learning_curve.html

# %%
from sklearn.model_selection import learning_curve
    
# evaluate the training and testing and retrieve the information of model performance. 

train_sizes = np.linspace(.2, .8, 5)

train_sizes, train_mse, test_mse = learning_curve(linreg, X, y,
                                                  train_sizes = train_sizes,
                                                  scoring='neg_mean_squared_error',
                                                  cv=3, shuffle=True)


train_scores = np.sqrt(np.abs(train_mse))
test_scores = np.sqrt(np.abs(test_mse))


train_scores_mean = np.mean(train_scores, axis = 1)
test_scores_mean = np.mean(test_scores, axis = 1)

# Plot learning curve
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
    
ax.set_title('A learning curve for a simple linear regression')
ax.set_xlabel("Training examples")
ax.set_ylabel("Score (RMSE)")
ax.grid()

ax.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
ax.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
ax.legend(loc="best")

plt.show()

# %% [markdown]
# ### Teamwork
#
#
# ###  Part 1: Explore insight of the data using other visualization tools
#
# The following Git repository is for the COVID-19 visual dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering:
# https://github.com/CSSEGISandData/COVID-19
#
# Read the information on the dashboard and check the datasets details
#
# Datasets are located in a folder: csse_covid_19_data

# %% [markdown]
# ### Tasks
#
# 1. Select attributes (columns) you are interested (either US only or all data).
#
#    1.1 (optional) If you find any missing data or/and invalid data in the selected attributes you would like to work on, apply tools to handle these data.
#
# 2. Conduct exploratory data analysis on the selected data and visualize the data. This may include the following but not limited:
#
# (a) The mean, median and standard deviation
#
# (b) Draw boxplots
#
# (c) Draw histograms
#
# (d) Draw a scatter plot of the data
#
# (e) Display simple linear regression function with a scatter plot
#     --> You will see the data does not follow a simple linear function.
#
# (f) Create a logistic regression function instead of a simple linear regression. See the web resources below:
#
#     from sklearn.linear_model import LogisticRegression
#
# This time draw a scatter plot of the data together with the logistic regression function.

# %%
# Download the data, code edited from above
import os
import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/"
os.makedirs(datapath, exist_ok=True)

for filename in ("time_series_covid19_deaths_global.csv", "time_series_covid19_confirmed_global.csv", "time_series_covid19_recovered_global.csv"):
    print("Downloading", filename)
    url = DOWNLOAD_ROOT + filename
    urllib.request.urlretrieve(url, datapath + filename)

# %%
# Load code edited from above
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
globalConfirmed = pd.read_csv(datapath + "time_series_covid19_confirmed_global.csv")
globalDeaths = pd.read_csv(datapath + "time_series_covid19_deaths_global.csv")
globalRecovered = pd.read_csv(datapath + "time_series_covid19_recovered_global.csv")

# %%
print("Confirmed:\n", globalConfirmed.info())
print("\nDeaths:\n", globalDeaths.info())
print("\nRecovered:\n", globalRecovered.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Columns: 365 entries, Province/State to 1/16/21
# dtypes: float64(2), int64(361), object(2)
# memory usage: 775.8+ KB
# Confirmed:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Columns: 365 entries, Province/State to 1/16/21
# dtypes: float64(2), int64(361), object(2)
# memory usage: 775.8+ KB
#
# Deaths:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Columns: 365 entries, Province/State to 1/16/21
# dtypes: float64(2), int64(361), object(2)
# memory usage: 733.0+ KB
#
# Recovered:
#  None

# %%
#print(mean)
print("Confirmed:\n", globalConfirmed.mean())
print("\nDeaths:\n", globalDeaths.mean())
print("\nRecovered:\n", globalRecovered.mean())
# Out:
# Confirmed:
#  Lat            20.688275
# Long           22.695528
# 1/22/20         2.047794
# 1/23/20         2.408088
# 1/24/20         3.459559
#                ...
# 1/12/21    336783.334559
# 1/13/21    339541.411765
# 1/14/21    342317.970588
# 1/15/21    345133.110294
# 1/16/21    347409.569853
# Length: 363, dtype: float64
#
# Deaths:
#  Lat          20.688275
# Long         22.695528
# 1/22/20       0.062500
# 1/23/20       0.066176
# 1/24/20       0.095588
#               ...
# 1/12/21    7214.569853
# 1/13/21    7274.783088
# 1/14/21    7331.080882
# 1/15/21    7386.367647
# 1/16/21    7434.283088
# Length: 363, dtype: float64
#
# Recovered:
#  Lat            19.253426
# Long           28.187637
# 1/22/20         0.116732
# 1/23/20         0.124514
# 1/24/20         0.151751
#                ...
# 1/12/21    197001.657588
# 1/13/21    198423.389105
# 1/14/21    199857.295720
# 1/15/21    201112.268482
# 1/16/21    202357.280156
# Length: 363, dtype: float64

# %%
print("Confirmed:\n", globalConfirmed.median())
print("\nDeaths:\n", globalDeaths.median())
print("\nRecovered:\n", globalRecovered.median())
# Out:
# Confirmed:
#  Lat           21.9162
# Long          20.9394
# 1/22/20        0.0000
# 1/23/20        0.0000
# 1/24/20        0.0000
#               ...
# 1/12/21     9845.0000
# 1/13/21     9970.5000
# 1/14/21    10153.5000
# 1/15/21    10604.0000
# 1/16/21    10765.5000
# Length: 363, dtype: float64
#
# Deaths:
#  Lat         21.9162
# Long        20.9394
# 1/22/20      0.0000
# 1/23/20      0.0000
# 1/24/20      0.0000
#              ...
# 1/12/21    132.5000
# 1/13/21    133.0000
# 1/14/21    135.0000
# 1/15/21    138.0000
# 1/16/21    139.0000
# Length: 363, dtype: float64
#
# Recovered:
#  Lat          20.593684
# Long         24.603200
# 1/22/20       0.000000
# 1/23/20       0.000000
# 1/24/20       0.000000
#               ...
# 1/12/21    6331.000000
# 1/13/21    6351.000000
# 1/14/21    6543.000000
# 1/15/21    6621.000000
# 1/16/21    6689.000000
# Length: 363, dtype: float64

# %%
tConfirmed = globalConfirmed.loc[:,"1/22/20":].transpose()
tDeaths = globalDeaths.loc[:,"1/22/20":].transpose()
tRecovered = globalRecovered.loc[:,"1/22/20":].transpose()
tConfirmed.columns = globalConfirmed['Country/Region']
tDeaths.columns = globalDeaths['Country/Region']
tRecovered.columns = globalRecovered['Country/Region']

# %%
tConfirmed = tConfirmed.groupby(tConfirmed.columns, axis=1).sum()
tDeaths = tDeaths.groupby(tDeaths.columns, axis=1).sum()
tRecovered = tRecovered.groupby(tRecovered.columns, axis=1).sum()

# %%
x = np.c_[range(0, len(tDeaths.index))]
for column in tConfirmed.columns:
    plt.scatter(x, tConfirmed[column], s=.2)
plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Cases')
plt.title('Covid Cases by Country')
plt.show()

# %%
x = np.c_[range(0, len(tDeaths.index))]
for column in tDeaths.columns:
    plt.scatter(x, tDeaths[column], s=.2)
plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Deaths')
plt.title('Covid Deaths by Country')
plt.show()

# %%
x = np.c_[range(0, len(tDeaths.index))]
for column in tRecovered.columns:
    plt.scatter(x, tRecovered[column], s=.2)
plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Recoveries')
plt.title('Covid Recoveries by Country')
plt.show()

# %%
#France total covid deaths histogram
tDeaths['US'].hist(xrot = 45)
plt.title('Days of US Covid Death Totals')
plt.xlabel('Covid Deaths')
plt.ylabel('Days')
# Out:
# Text(0, 0.5, 'Days')

# %%
plt.boxplot(tDeaths['US'])
plt.ylabel('Covid Deaths')
plt.title('US Covid Deaths Boxplot')
plt.xticks([1],['US'])
# Out:
# ([<matplotlib.axis.XTick at 0x1c1c14a5160>], [Text(0, 0, 'US')])

# %%
x = np.c_[range(0, len(tDeaths.index))]
plt.scatter(x, tDeaths['US'], s=.2)
plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Deaths')
plt.title('US Covid Deaths')
plt.show()

# %%
# simple linear regression for France
from sklearn.linear_model import LinearRegression
X = np.c_[range(0, len(tDeaths.index))]
y = list(tDeaths['US'])

# Create a simple linear regression model
model = LinearRegression()

# Train the model (we use all data for training --> Later we will divide the data into training data and testing data)
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Plot scatterplot 
plt.scatter(X, y, c='red', label='observed', s=1)
plt.legend(loc='best')

plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Deaths')
plt.title('US Covid Deaths Linear Regression')

# plot the regression function

plt.plot(X, model.predict(X), c='g', label='fitted', linewidth=2)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter =1000)

model.fit(X,y)
# Out:
# C:\Users\Thomas\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
# Plot scatterplot 
plt.scatter(X, y, c='red', label='observed', s = 1)
plt.legend(loc='best')

plt.xlabel('Days Since 1/22/20')
plt.ylabel('Covid Deaths')
plt.title('US Covid Deaths Logistical Regression')

# plot the regression function

plt.plot(X, model.predict(X), c='g', label='fitted', linewidth=2)
plt.show()

# %% [markdown]
# ### Part 2: Write a summary of what you find from the data

# %% [markdown]
#    From this Teamwork assignment I learned about training and test sets, linear regressions, and logistical regression. I found in the logistical regression it was important to increas the number of training iterations to help it fit the data. While these models aren't very useful as is, I learned the importance of understanding the data to design a useful model.
#
# Team Members:
#
# -Thomas Bakken https://github.com/thomasbakken-su/CPSC5310_TW3
#
# -Oleg Kovalenko https://github.com/okovko/su_ml_wq2021/tree/master/TW2

# %% [markdown]
# ### Submit your summary to Canvas
